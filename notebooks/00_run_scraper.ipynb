# %%
# %load_ext autoreload
# %autoreload 2
import sys
import os

project_path = "/Workspace/Users/matumazparrote@gmail.com/top_5_european_leagues"

if project_path not in sys.path:
    sys.path.append(project_path)

from src.scripts.scrapper import Scrapper

# %%
dbutils.widgets.text("year", "")
year = int(dbutils.widgets.get("year")) if dbutils.widgets.get("year") else 2023

print("Running scraper for year:", year)

# %%
scrapper = Scrapper(year)
scrapper.extract_links()
scrapper.save_csv_files()
